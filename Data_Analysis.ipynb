# %% [markdown]
# <a href="https://colab.research.google.com/github/WillowHealth/google_colab/blob/main/Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Libraries

# %%
import os
import pandas as pd
from pathlib import Path  
import plotly.express as px

# %% [markdown]
# #Functions

# %%
# Get folder names in the master GDrive folder

def get_folder_names(parent_folder_path):
  folders = []
  for filename in os.listdir(parent_folder_path):
      if filename.endswith(".com"): 
          folders.append(filename)
  return folders

# %% [markdown]
# #Setup

# %%
parent_folder_path = '/content/drive/MyDrive/1_Willow/Product Development and Prototypes/0.5 Prototype 2022 App /Data Files/Integromat/'

# %%
folders_list = get_folder_names(parent_folder_path)

# %%
def read_user_csv(id):
  path_csv = parent_folder_path + folders_list[id] + "/" + "merged_data_" + folders_list[id] + ".csv"
  df = pd.read_csv(path_csv)
  return df

# %%
df = read_user_csv(2)

# %%
df
# Out:
#       Active Energy (kcal)  Apple Stand Time (min)  \
# 0                      NaN                     NaN
# 1                      NaN                     NaN
# 2                      NaN                     NaN
# 3                      NaN                     NaN
# 4                      NaN                     NaN
# ...                    ...                     ...
# 1045                   NaN                     NaN
# 1046                   NaN                     NaN
# 1047                   NaN                     NaN
# 1048                   NaN                     NaN
# 1049                   NaN                     NaN
#
#       Basal Energy Burned (kcal)  Heart Rate [Min] (count/min)  \
# 0                            NaN                           NaN
# 1                            NaN                           NaN
# 2                            NaN                           NaN
# 3                            NaN                           NaN
# ...

# %%
df_sleep = df[['Date', 'Time', 'Sleep Analysis [Asleep] (hr)', 'Sleep Analysis [In Bed] (hr)']].dropna()

# %%
df_sleep
# Out:
#             Date      Time  Sleep Analysis [Asleep] (hr)  \
# 14    2022-08-26  02:00:00                           0.0
# 25    2022-08-27  01:00:00                           0.0
# 38    2022-08-28  01:00:00                           0.0
# 49    2022-08-29  04:00:00                           0.0
# 65    2022-08-30  06:00:00                           0.0
# ...          ...       ...                           ...
# 974   2022-10-21  03:00:00                           0.0
# 1000  2022-10-23  00:00:00                           0.0
# 1012  2022-10-24  06:00:00                           0.0
# 1024  2022-10-25  01:00:00                           0.0
# 1039  2022-10-26  01:00:00                           0.0
#
#       Sleep Analysis [In Bed] (hr)
# 14                        5.420564
# 25                        6.479550
# 38                        5.698724
# 49                        6.488170
# 65                        6.487858
# ...                            ...
# ...

# %%
fig = px.line(df_sleep, x="Date", y="Sleep Analysis [In Bed] (hr)", title='Sleep Analysis of Morgan')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import statistics

# %%
statistics.stdev(df_sleep['Sleep Analysis [In Bed] (hr)'])
# Out:
# 1.2505001941513307

# %%
df = read_user_csv(0)
df_sleep = df[['Date', 'Time', 'Sleep Analysis [Asleep] (hr)', 'Sleep Analysis [In Bed] (hr)']].dropna()
fig = px.line(df_sleep, x="Date", y="Sleep Analysis [In Bed] (hr)", title='Sleep Analysis of Catherine')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
